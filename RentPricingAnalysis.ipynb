# %% [markdown]
# # Digital Arch. Final Project: Rent Pricing Analysis

# %%
from ZillowModule.ZillowScraper import ZillowScraper
from ZillowModule.ZillowModel import ZillowModel

# %% [markdown]
# ### Create a list of zipcodes the user is interested in exploring

# %%
zipCodes = ['37920', '37076']

# %% [markdown]
# ### Use the ZillowScraper module to extract rent listings from the zipcodes and store it in our database

# %%
zs = ZillowScraper(zipCodes)
# Out:
# getting a list of proxies
# 865 proxies found
# checking proxy connection...
# proxy found: 123.245.249.185:8089
# checking proxy connection...
# proxy found: 95.217.210.191:8080
# checking proxy connection...
# proxy found: 223.215.176.37:8089
# checking proxy connection...
# proxy found: 132.255.210.117:999

# %% [markdown]
# ### Utilize deep learning model for regression task of predicting rent pricing for user specified zipcodes

# %%
zm = ZillowModel(zipCodes)
# Out:
# 3/3 [==============================] - 0s 1ms/step
# RMSE: 540.1303545721923

# %% [markdown]
# ### Use trained model to predict pricing for user specified parameters

# %%
inputs = {
  'zipCode':37920,
  'numBeds':1,
  'numBaths':1, 
  'area':750
}

pred = zm.ModelPredict(inputs)
print(pred)
# Out:
# 1382.15478515625

# %% [markdown]
# ### Plot Choropleth Maps

# %%
from VisualizeModule.RentMap import RentMap
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
rm = RentMap('New York', 'NY')
rm.GenerateChoroplethMap()

# %% [markdown]
# <img src="ASSAULT.png" alt="Image 1" style="width: 33%; display: inline-block;">
# <img src="ROBBERY.png" alt="Image 2" style="width: 33%; display: inline-block;">
# <img src="MURDER.png" alt="Image 3" style="width: 33%; display: inline-block;">

# %% [markdown]
# <span style="font-size: xx-large;">**Visualize Rent**</span>

# %%
from VisualizeModule.Visualize import Visualize
vis = Visualize()

# %%
vis.CorrelationHeatMap(zipCodes[0])
zip_code = ""

# %%
vis.CorrelationHeatMaps(zipCodes)

# %%
vis.FeatureBoxPlot(zipCodes, "price")

# %%
vis.FeatureBoxPlot(zipCodes, "numBeds")

# %%
vis.FeatureBoxPlot(zipCodes, "numBaths")

# %%
vis.FeatureBoxPlot(zipCodes, "area")

# %%
vis.ScatterTimeVPrice(zipCodes[0], feature="price")

# %%
vis.AddressWordCloud(zipCodes[0], price_threshold_lb=0, price_threshold_ub=5000)

# %%
vis.GeoSpatialMap(zipCodes[0])
